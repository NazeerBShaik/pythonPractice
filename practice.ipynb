# %%
print("Hey its a practice program")
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Rahul/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
create table customers
(
    id int,
    first_name varchar,
    last_name varchar,
    age int,
    gender varchar

)
insert into customers values
(1, nazeer, basha, 29, M),
(2, karthik, gudluru, 32, F)
# Out:
# Running cells with 'Python 3.13.7' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Rahul/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'
